# %%
import pandas as pd

# %%
df = pd.read_csv("/content/salaries.csv")
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k  Unnamed: 4
# 0  google      sales executive  bachelors                    0.0         NaN
# 1  google      sales executive    masters                    0.0         NaN
# 2  google     business manager  bachelors                    1.0         NaN
# 3  google     business manager    masters                    1.0         NaN
# 4  google  computer programmer  bachelors                    0.0         NaN

# %%
input = df.drop('salary_more_then_100k',axis = 'columns')

# %%
target = df['salary_more_then_100k'].astype('Int64')

# %%
target.drop(16)
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# Name: salary_more_then_100k, dtype: Int64

# %% [markdown]
# **Converting Labels into Numbers** <br>
# (cause machine laerning dont understand labels but numbers)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %%
input ['company_n'] = le_company.fit_transform(input['company'])
input ['job_n'] = le_job.fit_transform(input['job'])
input ['degree_n'] = le_degree.fit_transform(input['degree'])

# %%
input.drop(16)
# Out:
#        company                  job     degree  Unnamed: 4  company_n  job_n  \
# 0       google      sales executive  bachelors         NaN          2      2
# 1       google      sales executive    masters         NaN          2      2
# 2       google     business manager  bachelors         NaN          2      0
# 3       google     business manager    masters         NaN          2      0
# 4       google  computer programmer  bachelors         NaN          2      1
# 5       google  computer programmer    masters         NaN          2      1
# 6   abc pharma      sales executive    masters         NaN          0      2
# 7   abc pharma  computer programmer  bachelors         NaN          0      1
# 8   abc pharma     business manager  bachelors         NaN          0      0
# 9   abc pharma     business manager    masters         NaN          0      0
# 10    facebook      sales executive  bachelors         NaN          1      2
# 11    facebook      sales executive    masters         NaN          1      2
# 12    facebook     business manager  bachelors         NaN          1      0
# 13    facebook     business manager    masters         NaN          1      0
# 14    facebook  computer programmer  bachelors         NaN          1      1
# 15    facebook  computer programmer    masters         NaN          1      1
#
#     degree_n
# 0          0
# 1          1
# 2          0
# 3          1
# 4          0
# 5          1
# 6          1
# 7          0
# 8          0
# 9          1
# 10         0
# 11         1
# 12         0
# 13         1
# 14         0
# 15         1

# %%
input_n = input.drop(['company' , 'job' , 'degree','Unnamed: 4'], axis = 'columns')

# %%
input_n
# Out:
#     company_n  job_n  degree_n
# 0           2      2         0
# 1           2      2         1
# 2           2      0         0
# 3           2      0         1
# 4           2      1         0
# 5           2      1         1
# 6           0      2         1
# 7           0      1         0
# 8           0      0         0
# 9           0      0         1
# 10          1      2         0
# 11          1      2         1
# 12          1      0         0
# 13          1      0         1
# 14          1      1         0
# 15          1      1         1
# 16          3      3         2

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(input_n, target)

# %%
model.score(input_n,target)

# %%
model.predict([[2,1,0]])
model.predict([[2,1,1]])
